# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define Amdahl's Law function
def amdahls_speedup(P, N):
    """Calculates speedup according to Amdahl's Law."""
    N = np.asarray(N) 
    if P == 1:
        return N
    return 1 / ((1 - P) + (P / N))

# 2. Define the range for N (Number of Processors) as powers of two
power_of_two_exponents = np.arange(0, 17) # 0 to 16
N_values_discrete = 2**power_of_two_exponents

# For a smoother curve for plotting, use a dense range
N_values_dense = np.linspace(1, 65536, 500) 

# 3. Define the P values (Fraction of parallelizable code)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# 4. Create the plot
plt.figure(figsize=(15, 8)) # Slightly larger figure for readability

# Determine the x-position for the asymptote labels (slightly beyond the right edge of the plot)
# We'll extend the x-axis limits slightly to make space for these labels
max_N_for_plot = 65536


# Loop through each P value and plot the speedup curve
for P in P_values:
    # Use the dense N_values for plotting the smooth curve
    speedups_dense = amdahls_speedup(P, N_values_dense)
    
    # Calculate the theoretical maximum speedup for this P (as N -> infinity)
    max_speedup_theoretical = 1 / (1 - P)
    
    # Plot the main function line
    line, = plt.plot(N_values_dense, speedups_dense, label=f'P={P:.2f}') # Removed max speedup from legend

    # Plot the horizontal asymptote (max theoretical speedup)
    plt.axhline(y=max_speedup_theoretical, 
                color=line.get_color(),     
                linestyle=':',              
                alpha=0.95,                  
                linewidth=1.5)              
    
    # Add a text label for the asymptote
    if P == 0.75:
        x_label_pos = max_N_for_plot * 0.8 # Place label 3% beyond the max N for better visibility
        va='bottom'
    else: 
        x_label_pos = max_N_for_plot * 1.10 # Place label 3% beyond the max N for better visibility
        va='center'
    plt.text(x_label_pos, max_speedup_theoretical, 
             f'{max_speedup_theoretical:.0f}x', # Format as integer with 'x' suffix
             color=line.get_color(), 
             ha='left', va=va, # Horizontal alignment: left, Vertical alignment: center
             fontsize=24, 
             fontweight='bold')


# 5. Customize the plot
plt.xscale('log') 

# Set custom x-axis ticks and labels
plt.xticks(N_values_discrete, [str(n) for n in N_values_discrete], fontsize=24, fontweight='bold')
plt.tick_params(axis='x', rotation=90, size=24) 

plt.xlabel('Number of Processors (N)', fontsize=24,fontweight='bold')

# >>> REMOVE ALL OTHER Y LABELS <<<
plt.ylabel('Speedup', fontsize=24,fontweight='bold')
plt.yticks([]) # Remove all y-axis ticks and their labels

plt.title("Amdahl's Law: Speedup vs. Number of Processors (Powers of 2)", fontsize=24, fontweight='bold')
plt.grid(True, which="both", ls="--", c='0.7', alpha=0.7) 
plt.legend(title='Fraction Parallel (P)', loc='upper left', fontsize=24)

plt.ylim(1, 120) 
plt.xlim(1, max_N_for_plot * 1.05) # Extend x-axis limits to ensure labels are visible

plt.tight_layout() 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define Amdahl's Law function
def amdahls_speedup(P, N):
    """Calculates speedup according to Amdahl's Law."""
    N = np.asarray(N) 
    if P == 1:
        return N
    return 1 / ((1 - P) + (P / N))

# 2. Define the range for N (Number of Processors) as powers of two
power_of_two_exponents = np.arange(0, 17) # 0 to 16
N_values_discrete = 2**power_of_two_exponents

# For a smoother curve for plotting, use a dense range
N_values_dense = np.linspace(1, 65536, 500) 

# 3. Define the P values (Fraction of parallelizable code)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# 4. Create the plot
plt.figure(figsize=(15, 8)) # Slightly larger figure for readability

# Determine the x-position for the asymptote labels (slightly beyond the right edge of the plot)
# We'll extend the x-axis limits slightly to make space for these labels
max_N_for_plot = 128


# Loop through each P value and plot the speedup curve
for P in P_values:
    # Use the dense N_values for plotting the smooth curve
    speedups_dense = amdahls_speedup(P, N_values_dense)
    
    # Calculate the theoretical maximum speedup for this P (as N -> infinity)
    max_speedup_theoretical = 1 / (1 - P)
    
    # Plot the main function line
    line, = plt.plot(N_values_dense, speedups_dense, label=f'P={P:.2f}') # Removed max speedup from legend

    # Plot the horizontal asymptote (max theoretical speedup)
    plt.axhline(y=max_speedup_theoretical, 
                color=line.get_color(),     
                linestyle=':',              
                alpha=0.95,                  
                linewidth=1.5)              
    
    # Add a text label for the asymptote
    if P == 0.75:
        x_label_pos = max_N_for_plot * 0.8 # Place label 3% beyond the max N for better visibility
        va='bottom'
    else: 
        x_label_pos = max_N_for_plot * 1.10 # Place label 3% beyond the max N for better visibility
        va='center'
    plt.text(x_label_pos, max_speedup_theoretical, 
             f'{max_speedup_theoretical:.0f}x', # Format as integer with 'x' suffix
             color=line.get_color(), 
             ha='left', va=va, # Horizontal alignment: left, Vertical alignment: center
             fontsize=24, 
             fontweight='bold')


# 5. Customize the plot
plt.xscale('log') 

# Set custom x-axis ticks and labels
plt.xticks(N_values_discrete, [str(n) for n in N_values_discrete], fontsize=24, fontweight='bold')
plt.tick_params(axis='x', rotation=90, size=24) 

plt.xlabel('Number of Processors (N)', fontsize=24,fontweight='bold')

# >>> REMOVE ALL OTHER Y LABELS <<<
plt.ylabel('Speedup', fontsize=24,fontweight='bold')
plt.yticks([]) # Remove all y-axis ticks and their labels

plt.title("Amdahl's Law: Speedup vs. Number of Processors (Powers of 2)", fontsize=24, fontweight='bold')
plt.grid(True, which="both", ls="--", c='0.7', alpha=0.7) 
plt.legend(title='Fraction Parallel (P)', loc='upper left', fontsize=24)

plt.ylim(1, 120) 
plt.xlim(1, max_N_for_plot * 1.05) # Extend x-axis limits to ensure labels are visible

plt.tight_layout() 
plt.show()

# %%
import pandas as pd

# Define the original computation time
T_original_hours = 24

# Define the P values (rows)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# Define the N values (columns)
N_values = [1, 2, 8, 128, 512, 16384]

# Function to calculate speedup using Amdahl's Law
def amdahls_speedup(P, N):
    if P == 1: # Fully parallelizable, ideal speedup is N
        return N
    return 1 / ((1 - P) + (P / N))

# Create a list to hold the rows of our table
table_rows = []

# Iterate through each P value to create a row
for P in P_values:
    row_data = [f'{P:.2f}'] # Start the row with the P value, formatted
    
    for N in N_values:
        speedup = amdahls_speedup(P, N)
        time_taken_hours = T_original_hours / speedup
        # Format the time directly in hours to two decimal places
        row_data.append(f'{time_taken_hours:.2f}') 
        
    table_rows.append(row_data)

# Define column headers
column_headers = ['P (Parallel Fraction)'] + [f'N={n}' for n in N_values]

# Create a Pandas DataFrame
df = pd.DataFrame(table_rows, columns=column_headers)

# Display the table
print(f"Computation Time (Original Time: {T_original_hours} hours) - All values in hours")
print("-" * (len(df.columns) * 12)) # Simple separator
print(df.to_string(index=False)) # Use to_string() to display full table without truncation
# Out:
# Computation Time (Original Time: 24 hours) - All values in hours
# ------------------------------------------------------------------------------------
# P (Parallel Fraction)   N=1   N=2   N=8 N=128 N=512 N=16384
#                  0.50 24.00 18.00 13.50 12.09 12.02   12.00
#                  0.75 24.00 15.00  8.25  6.14  6.04    6.00
#                  0.90 24.00 13.20  5.10  2.57  2.44    2.40
#                  0.95 24.00 12.60  4.05  1.38  1.24    1.20
#                  0.99 24.00 12.12  3.21  0.43  0.29    0.24

# %%
import pandas as pd
from IPython.display import display, HTML # For displaying styled DataFrame in environments like Jupyter

# Define the original computation time
T_original_hours = 24

# Define the P values (rows)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# Define the N values (columns)
N_values = [1, 2, 8, 128, 512, 16384]

# Function to calculate speedup using Amdahl's Law
def amdahls_speedup(P, N):
    if P == 1: # Fully parallelizable, ideal speedup is N
        return N
    return 1 / ((1 - P) + (P / N))

# Create a list to hold the rows of our table (storing raw float values now)
table_rows_float = []

# Iterate through each P value to create a row
for P in P_values:
    row_data_float = [P] # P value as a float
    
    for N in N_values:
        speedup = amdahls_speedup(P, N)
        time_taken_hours = T_original_hours / speedup
        row_data_float.append(time_taken_hours)
        
    table_rows_float.append(row_data_float)

# Define column headers
column_headers = ['P'] + [f'N={n}' for n in N_values]

# Create a Pandas DataFrame
df = pd.DataFrame(table_rows_float, columns=column_headers)

# --- Styling the DataFrame for Presentation ---

# Function to highlight the minimum value in a row (excluding the P column)
def highlight_min_time(s):
    # 's' here is a pandas Series representing a row of time values
    # We only want to consider the numerical time columns for min
    numerical_values = s.drop('P', errors='ignore') 
    is_min = numerical_values == numerical_values.min()
    # Create a Series of styles for the original row, setting empty for 'P' column
    styles = ['' for _ in s.index]
    for i, col_name in enumerate(s.index):
        if col_name != 'P':
            if col_name in is_min.index and is_min.loc[col_name]:
                styles[i] = 'background-color: #d4edda' # Light green background for min
    return styles


# Create a single dictionary for all formatting
format_mapping = {}
format_mapping['P'] = "{:.2f}" # Format P column to 2 decimal places
for col in df.columns[1:]: # For all N columns
    format_mapping[col] = "{:.2f}" # Format all time values to 2 decimal places


# Apply styling
styler = df.style.hide(axis="index") \
    .format(format_mapping) \
    .set_table_styles([
        # Header styles
        {'selector': 'th', 'props': [
            ('font-weight', 'bold'),
            ('background-color', '#e9ecef'), # Light grey header background
            ('text-align', 'center'),
            ('padding', '8px')
        ]},
        # Caption style
        {'selector': 'caption', 'props': [
            ('font-size', '1.2em'),
            ('font-weight', 'bold'),
            ('text-align', 'center'),
            ('padding', '10px')
        ]},
        # Hover effect for rows (interactive in HTML)
        {'selector': 'tr:hover', 'props': [('background-color', '#f8f9fa')]}, # Very light grey on hover
    ]) \
    .set_properties(subset=['P'], **{ # Style for the P column
        'text-align': 'center',
        'font-weight': 'bold',
        'background-color': '#f2f2f2' # Slightly darker grey for P column
    }) \
    .set_properties(subset=df.columns[1:], **{ # Style for N columns
        'text-align': 'center',
        'padding': '8px'
    }) \
    .apply(highlight_min_time, axis=1) \
    .set_table_styles([ # Add subtle borders (applied last to ensure borders are on top)
        {'selector': 'td, th', 'props': [('border', '1px solid #dee2e6')]}
    ], overwrite=False)


# Display the styled DataFrame
display(styler)

# If you need to save it as an HTML file for embedding:
# styler.to_html("amdahls_table.html")
# print("Table saved as amdahls_table.html")
# Out:
# <style type="text/css">
# #T_9de4d th {
#   font-weight: bold;
#   background-color: #e9ecef;
#   text-align: center;
#   padding: 8px;
# }
# #T_9de4d caption {
#   font-size: 1.2em;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_9de4d tr:hover {
#   background-color: #f8f9fa;
# }
# #T_9de4d td {
#   border: 1px solid #dee2e6;
# }
# #T_9de4d  th {
#   border: 1px solid #dee2e6;
# }
# #T_9de4d_row0_col0, #T_9de4d_row1_col0, #T_9de4d_row2_col0, #T_9de4d_row3_col0, #T_9de4d_row4_col0 {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f2f2f2;
# }
# #T_9de4d_row0_col1, #T_9de4d_row0_col2, #T_9de4d_row0_col3, #T_9de4d_row0_col4, #T_9de4d_row0_col5, #T_9de4d_row1_col1, #T_9de4d_row1_col2, #T_9de4d_row1_col3, #T_9de4d_row1_col4, #T_9de4d_row1_col5, #T_9de4d_row2_col1, #T_9de4d_row2_col2, #T_9de4d_row2_col3, #T_9de4d_row2_col4, #T_9de4d_row2_col5, #T_9de4d_row3_col1, #T_9de4d_row3_col2, #T_9de4d_row3_col3, #T_9de4d_row3_col4, #T_9de4d_row3_col5, #T_9de4d_row4_col1, #T_9de4d_row4_col2, #T_9de4d_row4_col3, #T_9de4d_row4_col4, #T_9de4d_row4_col5 {
#   text-align: center;
#   padding: 8px;
# }
# #T_9de4d_row0_col6, #T_9de4d_row1_col6, #T_9de4d_row2_col6, #T_9de4d_row3_col6, #T_9de4d_row4_col6 {
#   text-align: center;
#   padding: 8px;
#   background-color: #d4edda;
# }
# </style>
# <table id="T_9de4d">
#   <thead>
#     <tr>
#       <th id="T_9de4d_level0_col0" class="col_heading level0 col0" >P</th>
#       <th id="T_9de4d_level0_col1" class="col_heading level0 col1" >N=1</th>
#       <th id="T_9de4d_level0_col2" class="col_heading level0 col2" >N=2</th>
#       <th id="T_9de4d_level0_col3" class="col_heading level0 col3" >N=8</th>
#       <th id="T_9de4d_level0_col4" class="col_heading level0 col4" >N=128</th>
#       <th id="T_9de4d_level0_col5" class="col_heading level0 col5" >N=512</th>
#       <th id="T_9de4d_level0_col6" class="col_heading level0 col6" >N=16384</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9de4d_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_9de4d_row0_col1" class="data row0 col1" >24.00</td>
#       <td id="T_9de4d_row0_col2" class="data row0 col2" >18.00</td>
#       <td id="T_9de4d_row0_col3" class="data row0 col3" >13.50</td>
#       <td id="T_9de4d_row0_col4" class="data row0 col4" >12.09</td>
#       <td id="T_9de4d_row0_col5" class="data row0 col5" >12.02</td>
#       <td id="T_9de4d_row0_col6" class="data row0 col6" >12.00</td>
#     </tr>
#     <tr>
#       <td id="T_9de4d_row1_col0" class="data row1 col0" >0.75</td>
#       <td id="T_9de4d_row1_col1" class="data row1 col1" >24.00</td>
#       <td id="T_9de4d_row1_col2" class="data row1 col2" >15.00</td>
#       <td id="T_9de4d_row1_col3" class="data row1 col3" >8.25</td>
#       <td id="T_9de4d_row1_col4" class="data row1 col4" >6.14</td>
#       <td id="T_9de4d_row1_col5" class="data row1 col5" >6.04</td>
#       <td id="T_9de4d_row1_col6" class="data row1 col6" >6.00</td>
#     </tr>
#     <tr>
#       <td id="T_9de4d_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_9de4d_row2_col1" class="data row2 col1" >24.00</td>
#       <td id="T_9de4d_row2_col2" class="data row2 col2" >13.20</td>
#       <td id="T_9de4d_row2_col3" class="data row2 col3" >5.10</td>
#       <td id="T_9de4d_row2_col4" class="data row2 col4" >2.57</td>
#       <td id="T_9de4d_row2_col5" class="data row2 col5" >2.44</td>
#       <td id="T_9de4d_row2_col6" class="data row2 col6" >2.40</td>
#     </tr>
#     <tr>
#       <td id="T_9de4d_row3_col0" class="data row3 col0" >0.95</td>
#       <td id="T_9de4d_row3_col1" class="data row3 col1" >24.00</td>
#       <td id="T_9de4d_row3_col2" class="data row3 col2" >12.60</td>
#       <td id="T_9de4d_row3_col3" class="data row3 col3" >4.05</td>
#       <td id="T_9de4d_row3_col4" class="data row3 col4" >1.38</td>
#       <td id="T_9de4d_row3_col5" class="data row3 col5" >1.24</td>
#       <td id="T_9de4d_row3_col6" class="data row3 col6" >1.20</td>
#     </tr>
#     <tr>
#       <td id="T_9de4d_row4_col0" class="data row4 col0" >0.99</td>
#       <td id="T_9de4d_row4_col1" class="data row4 col1" >24.00</td>
#       <td id="T_9de4d_row4_col2" class="data row4 col2" >12.12</td>
#       <td id="T_9de4d_row4_col3" class="data row4 col3" >3.21</td>
#       <td id="T_9de4d_row4_col4" class="data row4 col4" >0.43</td>
#       <td id="T_9de4d_row4_col5" class="data row4 col5" >0.29</td>
#       <td id="T_9de4d_row4_col6" class="data row4 col6" >0.24</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
from IPython.display import display, HTML # For displaying styled DataFrame in environments like Jupyter

# --- Anchor Point and Calculated Original Time ---
P_anchor = 0.99
N_anchor = 16384
Time_anchor_ms = 100 # milliseconds

# Function to calculate speedup using Amdahl's Law
def amdahls_speedup(P, N):
    if P == 1: 
        return N
    return 1 / ((1 - P) + (P / N))

# Calculate the speedup at the anchor point
speedup_at_anchor = amdahls_speedup(P_anchor, N_anchor)

# Calculate the effective original time (T1) in milliseconds
T_original_ms = Time_anchor_ms * speedup_at_anchor
print(f"Calculated Original Time (T1) on 1 processor: {T_original_ms:.2f} ms (~{T_original_ms/1000:.2f} seconds)\n")

# Define the P values (rows)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# Define the N values (columns)
N_values = [1, 2, 8, 128, 512, 16384]

# Helper function to format milliseconds into a human-readable string
def format_time_from_ms(ms_value):
    if ms_value is None:
        return ""
    
    # Use scientific notation for extremely small non-zero values
    if ms_value > 0 and ms_value < 0.0001:
        return f"{ms_value:.1e}ms" # e.g., 1.2e-5ms

    if ms_value < 1:
        if ms_value * 1000 < 1: # less than 1 microsecond
            return f"{ms_value * 1_000_000:.2f}ns"
        return f"{ms_value * 1000:.2f}µs"
    
    if ms_value < 1000: # less than 1 second
        return f"{ms_value:.2f}ms"

    # Now convert to seconds and format for larger units
    total_seconds = ms_value / 1000.0
    
    if total_seconds < 60:
        return f"{total_seconds:.2f}s"
    
    minutes = int(total_seconds // 60)
    remaining_seconds = total_seconds % 60
    
    if minutes < 60:
        return f"{minutes}m {remaining_seconds:.1f}s"
    
    hours = int(minutes // 60)
    minutes %= 60
    
    if hours < 24:
        return f"{hours}h {minutes:02}m {remaining_seconds:.0f}s"
    
    days = int(hours // 24)
    hours %= 24
    
    return f"{days}d {hours:02}h {minutes:02}m {remaining_seconds:.0f}s"


# Create a list to hold the rows of our table (storing raw float ms values)
table_rows_float = []

# Iterate through each P value to create a row
for P in P_values:
    row_data_float = [P] # P value as a float
    
    for N in N_values:
        speedup = amdahls_speedup(P, N)
        time_taken_ms = T_original_ms / speedup
        row_data_float.append(time_taken_ms)
        
    table_rows_float.append(row_data_float)

# Define column headers
column_headers = ['P'] + [f'N={n}' for n in N_values]

# Create a Pandas DataFrame
df = pd.DataFrame(table_rows_float, columns=column_headers)

# --- Styling the DataFrame for Presentation ---

# Function to highlight the minimum value in a row (excluding the P column)
def highlight_min_time(s):
    numerical_values = s.drop('P', errors='ignore') 
    is_min = numerical_values == numerical_values.min()
    styles = ['' for _ in s.index]
    for i, col_name in enumerate(s.index):
        if col_name != 'P': # Don't apply highlight to the 'P' column itself
            if col_name in is_min.index and is_min.loc[col_name]:
                styles[i] = 'background-color: #d4edda' # Light green background for min
    return styles


# Create a single dictionary for all formatting
format_mapping = {}
format_mapping['P'] = "{:.2f}" # Format P column to 2 decimal places
for col in df.columns[1:]: # For all N columns, use the custom time formatter
    format_mapping[col] = format_time_from_ms


# Apply styling
styler = df.style.hide(axis="index") \
    .set_caption(f"Amdahl's Law: Computation Time (Anchored at P={P_anchor:.2f}, N={N_anchor} = {Time_anchor_ms}ms)") \
    .format(format_mapping) \
    .set_table_styles([
        # Header styles
        {'selector': 'th', 'props': [
            ('font-weight', 'bold'),
            ('background-color', '#e9ecef'), 
            ('text-align', 'center'),
            ('padding', '8px')
        ]},
        # Caption style
        {'selector': 'caption', 'props': [
            ('font-size', '1.2em'),
            ('font-weight', 'bold'),
            ('text-align', 'center'),
            ('padding', '10px')
        ]},
        # Hover effect for rows (interactive in HTML)
        {'selector': 'tr:hover', 'props': [('background-color', '#f8f9fa')]}, 
    ]) \
    .set_properties(subset=['P'], **{ # Style for the P column
        'text-align': 'center',
        'font-weight': 'bold',
        'background-color': '#f2f2f2' 
    }) \
    .set_properties(subset=df.columns[1:], **{ # Style for N columns
        'text-align': 'center',
        'padding': '8px'
    }) \
    .apply(highlight_min_time, axis=1) \
    .set_table_styles([ # Add subtle borders (applied last to ensure borders are on top)
        {'selector': 'td, th', 'props': [('border', '1px solid #dee2e6')]}
    ], overwrite=False)


# Display the styled DataFrame
display(styler)

# To save as PDF (requires weasyprint or pdfkit as discussed previously)
# html_string = styler.to_html()
# from weasyprint import HTML, CSS
# HTML(string=html_string).write_pdf("amdahls_table_ms_anchor.pdf")
# print("Table saved as amdahls_table_ms_anchor.pdf")
# Out:
# Calculated Original Time (T1) on 1 processor: 9939.94 ms (~9.94 seconds)
# <style type="text/css">
# #T_f0907 th {
#   font-weight: bold;
#   background-color: #e9ecef;
#   text-align: center;
#   padding: 8px;
# }
# #T_f0907 caption {
#   font-size: 1.2em;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_f0907 tr:hover {
#   background-color: #f8f9fa;
# }
# #T_f0907 td {
#   border: 1px solid #dee2e6;
# }
# #T_f0907  th {
#   border: 1px solid #dee2e6;
# }
# #T_f0907_row0_col0, #T_f0907_row1_col0, #T_f0907_row2_col0, #T_f0907_row3_col0, #T_f0907_row4_col0 {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f2f2f2;
# }
# #T_f0907_row0_col1, #T_f0907_row0_col2, #T_f0907_row0_col3, #T_f0907_row0_col4, #T_f0907_row0_col5, #T_f0907_row1_col1, #T_f0907_row1_col2, #T_f0907_row1_col3, #T_f0907_row1_col4, #T_f0907_row1_col5, #T_f0907_row2_col1, #T_f0907_row2_col2, #T_f0907_row2_col3, #T_f0907_row2_col4, #T_f0907_row2_col5, #T_f0907_row3_col1, #T_f0907_row3_col2, #T_f0907_row3_col3, #T_f0907_row3_col4, #T_f0907_row3_col5, #T_f0907_row4_col1, #T_f0907_row4_col2, #T_f0907_row4_col3, #T_f0907_row4_col4, #T_f0907_row4_col5 {
#   text-align: center;
#   padding: 8px;
# }
# #T_f0907_row0_col6, #T_f0907_row1_col6, #T_f0907_row2_col6, #T_f0907_row3_col6, #T_f0907_row4_col6 {
#   text-align: center;
#   padding: 8px;
#   background-color: #d4edda;
# }
# </style>
# <table id="T_f0907">
#   <caption>Amdahl's Law: Computation Time (Anchored at P=0.99, N=16384 = 100ms)</caption>
#   <thead>
#     <tr>
#       <th id="T_f0907_level0_col0" class="col_heading level0 col0" >P</th>
#       <th id="T_f0907_level0_col1" class="col_heading level0 col1" >N=1</th>
#       <th id="T_f0907_level0_col2" class="col_heading level0 col2" >N=2</th>
#       <th id="T_f0907_level0_col3" class="col_heading level0 col3" >N=8</th>
#       <th id="T_f0907_level0_col4" class="col_heading level0 col4" >N=128</th>
#       <th id="T_f0907_level0_col5" class="col_heading level0 col5" >N=512</th>
#       <th id="T_f0907_level0_col6" class="col_heading level0 col6" >N=16384</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0907_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_f0907_row0_col1" class="data row0 col1" >9.94s</td>
#       <td id="T_f0907_row0_col2" class="data row0 col2" >7.45s</td>
#       <td id="T_f0907_row0_col3" class="data row0 col3" >5.59s</td>
#       <td id="T_f0907_row0_col4" class="data row0 col4" >5.01s</td>
#       <td id="T_f0907_row0_col5" class="data row0 col5" >4.98s</td>
#       <td id="T_f0907_row0_col6" class="data row0 col6" >4.97s</td>
#     </tr>
#     <tr>
#       <td id="T_f0907_row1_col0" class="data row1 col0" >0.75</td>
#       <td id="T_f0907_row1_col1" class="data row1 col1" >9.94s</td>
#       <td id="T_f0907_row1_col2" class="data row1 col2" >6.21s</td>
#       <td id="T_f0907_row1_col3" class="data row1 col3" >3.42s</td>
#       <td id="T_f0907_row1_col4" class="data row1 col4" >2.54s</td>
#       <td id="T_f0907_row1_col5" class="data row1 col5" >2.50s</td>
#       <td id="T_f0907_row1_col6" class="data row1 col6" >2.49s</td>
#     </tr>
#     <tr>
#       <td id="T_f0907_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_f0907_row2_col1" class="data row2 col1" >9.94s</td>
#       <td id="T_f0907_row2_col2" class="data row2 col2" >5.47s</td>
#       <td id="T_f0907_row2_col3" class="data row2 col3" >2.11s</td>
#       <td id="T_f0907_row2_col4" class="data row2 col4" >1.06s</td>
#       <td id="T_f0907_row2_col5" class="data row2 col5" >1.01s</td>
#       <td id="T_f0907_row2_col6" class="data row2 col6" >994.54ms</td>
#     </tr>
#     <tr>
#       <td id="T_f0907_row3_col0" class="data row3 col0" >0.95</td>
#       <td id="T_f0907_row3_col1" class="data row3 col1" >9.94s</td>
#       <td id="T_f0907_row3_col2" class="data row3 col2" >5.22s</td>
#       <td id="T_f0907_row3_col3" class="data row3 col3" >1.68s</td>
#       <td id="T_f0907_row3_col4" class="data row3 col4" >570.77ms</td>
#       <td id="T_f0907_row3_col5" class="data row3 col5" >515.44ms</td>
#       <td id="T_f0907_row3_col6" class="data row3 col6" >497.57ms</td>
#     </tr>
#     <tr>
#       <td id="T_f0907_row4_col0" class="data row4 col0" >0.99</td>
#       <td id="T_f0907_row4_col1" class="data row4 col1" >9.94s</td>
#       <td id="T_f0907_row4_col2" class="data row4 col2" >5.02s</td>
#       <td id="T_f0907_row4_col3" class="data row4 col3" >1.33s</td>
#       <td id="T_f0907_row4_col4" class="data row4 col4" >176.28ms</td>
#       <td id="T_f0907_row4_col5" class="data row4 col5" >118.62ms</td>
#       <td id="T_f0907_row4_col6" class="data row4 col6" >100.00ms</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
from IPython.display import display, HTML # For displaying styled DataFrame in environments like Jupyter

# --- Original Time ---
T_original_seconds = 10 # 10 seconds on a single processor

# Function to calculate speedup using Amdahl's Law
def amdahls_speedup(P, N):
    if P == 1: 
        return N
    return 1 / ((1 - P) + (P / N))

# Define the P values (rows)
P_values = [0.5, 0.75, 0.90, 0.95, 0.99]

# Define the N values (columns)
N_values = [1, 2, 8, 128, 512, 16384]

# Create a list to hold the rows of our table (storing raw float seconds values)
table_rows_float = []

# Iterate through each P value to create a row
for P in P_values:
    row_data_float = [P] # P value as a float
    
    for N in N_values:
        speedup = amdahls_speedup(P, N)
        time_taken_seconds = T_original_seconds / speedup
        row_data_float.append(time_taken_seconds)
        
    table_rows_float.append(row_data_float)

# Define column headers
column_headers = ['P'] + [f'N={n}' for n in N_values]

# Create a Pandas DataFrame
df = pd.DataFrame(table_rows_float, columns=column_headers)

# --- Styling the DataFrame for Presentation ---

# Function to highlight the minimum value in a row (excluding the P column)
def highlight_min_time(s):
    numerical_values = s.drop('P', errors='ignore') 
    is_min = numerical_values == numerical_values.min()
    styles = ['' for _ in s.index]
    for i, col_name in enumerate(s.index):
        if col_name != 'P': # Don't apply highlight to the 'P' column itself
            if col_name in is_min.index and is_min.loc[col_name]:
                styles[i] = 'background-color: #d4edda' # Light green background for min
    return styles


# Create a single dictionary for all formatting
format_mapping = {}
format_mapping['P'] = "{:.2f}" # Format P column to 2 decimal places

# All time values in seconds, formatted to 6 decimal places
for col in df.columns[1:]: # For all N columns
    format_mapping[col] = "{:.3f}s" # Fixed 6 decimal places with 's' suffix


# Apply styling
styler = df.style.hide(axis="index") \
    .format(format_mapping) \
    .set_table_styles([
        # Header styles
        {'selector': 'th', 'props': [
            ('font-weight', 'bold'),
            ('background-color', '#e9ecef'), 
            ('text-align', 'center'),
            ('padding', '8px')
        ]},
        # Caption style
        {'selector': 'caption', 'props': [
            ('font-size', '1.2em'),
            ('font-weight', 'bold'),
            ('text-align', 'center'),
            ('padding', '10px')
        ]},
        # Hover effect for rows (interactive in HTML)
        {'selector': 'tr:hover', 'props': [('background-color', '#f8f9fa')]}, 
    ]) \
    .set_properties(subset=['P'], **{ # Style for the P column
        'text-align': 'center',
        'font-weight': 'bold',
        'background-color': '#f2f2f2' 
    }) \
    .set_properties(subset=df.columns[1:], **{ # Style for N columns
        'text-align': 'center',
        'padding': '8px'
    }) \
    .apply(highlight_min_time, axis=1) \
    .set_table_styles([ # Add subtle borders (applied last to ensure borders are on top)
        {'selector': 'td, th', 'props': [('border', '1px solid #dee2e6')]}
    ], overwrite=False)


# Display the styled DataFrame
display(styler)

# To save as PDF (requires weasyprint or pdfkit as discussed previously)
# html_string = styler.to_html()
# from weasyprint import HTML, CSS
# HTML(string=html_string).write_pdf("amdahls_table_10s_original_in_seconds.pdf")
# print("Table saved as amdahls_table_10s_original_in_seconds.pdf")
# Out:
# <style type="text/css">
# #T_103d8 th {
#   font-weight: bold;
#   background-color: #e9ecef;
#   text-align: center;
#   padding: 8px;
# }
# #T_103d8 caption {
#   font-size: 1.2em;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_103d8 tr:hover {
#   background-color: #f8f9fa;
# }
# #T_103d8 td {
#   border: 1px solid #dee2e6;
# }
# #T_103d8  th {
#   border: 1px solid #dee2e6;
# }
# #T_103d8_row0_col0, #T_103d8_row1_col0, #T_103d8_row2_col0, #T_103d8_row3_col0, #T_103d8_row4_col0 {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f2f2f2;
# }
# #T_103d8_row0_col1, #T_103d8_row0_col2, #T_103d8_row0_col3, #T_103d8_row0_col4, #T_103d8_row0_col5, #T_103d8_row1_col1, #T_103d8_row1_col2, #T_103d8_row1_col3, #T_103d8_row1_col4, #T_103d8_row1_col5, #T_103d8_row2_col1, #T_103d8_row2_col2, #T_103d8_row2_col3, #T_103d8_row2_col4, #T_103d8_row2_col5, #T_103d8_row3_col1, #T_103d8_row3_col2, #T_103d8_row3_col3, #T_103d8_row3_col4, #T_103d8_row3_col5, #T_103d8_row4_col1, #T_103d8_row4_col2, #T_103d8_row4_col3, #T_103d8_row4_col4, #T_103d8_row4_col5 {
#   text-align: center;
#   padding: 8px;
# }
# #T_103d8_row0_col6, #T_103d8_row1_col6, #T_103d8_row2_col6, #T_103d8_row3_col6, #T_103d8_row4_col6 {
#   text-align: center;
#   padding: 8px;
#   background-color: #d4edda;
# }
# </style>
# <table id="T_103d8">
#   <thead>
#     <tr>
#       <th id="T_103d8_level0_col0" class="col_heading level0 col0" >P</th>
#       <th id="T_103d8_level0_col1" class="col_heading level0 col1" >N=1</th>
#       <th id="T_103d8_level0_col2" class="col_heading level0 col2" >N=2</th>
#       <th id="T_103d8_level0_col3" class="col_heading level0 col3" >N=8</th>
#       <th id="T_103d8_level0_col4" class="col_heading level0 col4" >N=128</th>
#       <th id="T_103d8_level0_col5" class="col_heading level0 col5" >N=512</th>
#       <th id="T_103d8_level0_col6" class="col_heading level0 col6" >N=16384</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_103d8_row0_col0" class="data row0 col0" >0.50</td>
#       <td id="T_103d8_row0_col1" class="data row0 col1" >10.000s</td>
#       <td id="T_103d8_row0_col2" class="data row0 col2" >7.500s</td>
#       <td id="T_103d8_row0_col3" class="data row0 col3" >5.625s</td>
#       <td id="T_103d8_row0_col4" class="data row0 col4" >5.039s</td>
#       <td id="T_103d8_row0_col5" class="data row0 col5" >5.010s</td>
#       <td id="T_103d8_row0_col6" class="data row0 col6" >5.000s</td>
#     </tr>
#     <tr>
#       <td id="T_103d8_row1_col0" class="data row1 col0" >0.75</td>
#       <td id="T_103d8_row1_col1" class="data row1 col1" >10.000s</td>
#       <td id="T_103d8_row1_col2" class="data row1 col2" >6.250s</td>
#       <td id="T_103d8_row1_col3" class="data row1 col3" >3.438s</td>
#       <td id="T_103d8_row1_col4" class="data row1 col4" >2.559s</td>
#       <td id="T_103d8_row1_col5" class="data row1 col5" >2.515s</td>
#       <td id="T_103d8_row1_col6" class="data row1 col6" >2.500s</td>
#     </tr>
#     <tr>
#       <td id="T_103d8_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_103d8_row2_col1" class="data row2 col1" >10.000s</td>
#       <td id="T_103d8_row2_col2" class="data row2 col2" >5.500s</td>
#       <td id="T_103d8_row2_col3" class="data row2 col3" >2.125s</td>
#       <td id="T_103d8_row2_col4" class="data row2 col4" >1.070s</td>
#       <td id="T_103d8_row2_col5" class="data row2 col5" >1.018s</td>
#       <td id="T_103d8_row2_col6" class="data row2 col6" >1.001s</td>
#     </tr>
#     <tr>
#       <td id="T_103d8_row3_col0" class="data row3 col0" >0.95</td>
#       <td id="T_103d8_row3_col1" class="data row3 col1" >10.000s</td>
#       <td id="T_103d8_row3_col2" class="data row3 col2" >5.250s</td>
#       <td id="T_103d8_row3_col3" class="data row3 col3" >1.688s</td>
#       <td id="T_103d8_row3_col4" class="data row3 col4" >0.574s</td>
#       <td id="T_103d8_row3_col5" class="data row3 col5" >0.519s</td>
#       <td id="T_103d8_row3_col6" class="data row3 col6" >0.501s</td>
#     </tr>
#     <tr>
#       <td id="T_103d8_row4_col0" class="data row4 col0" >0.99</td>
#       <td id="T_103d8_row4_col1" class="data row4 col1" >10.000s</td>
#       <td id="T_103d8_row4_col2" class="data row4 col2" >5.050s</td>
#       <td id="T_103d8_row4_col3" class="data row4 col3" >1.337s</td>
#       <td id="T_103d8_row4_col4" class="data row4 col4" >0.177s</td>
#       <td id="T_103d8_row4_col5" class="data row4 col5" >0.119s</td>
#       <td id="T_103d8_row4_col6" class="data row4 col6" >0.101s</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define the execution time function based on Amdahl's Law
def execution_time_amdahl(P, N, T1=1.0):
    """
    Calculates execution time according to Amdahl's Law, relative to T1 (original time).
    T1 is set to 1.0 for relative time (fraction of original time).
    """
    N = np.asarray(N)
    return T1 * ((1 - P) + (P / N))

# 2. Define the range for N (Number of Processors) for plotting dense curves
N_values_dense = np.linspace(1, 65536, 500)

# 3. Define the N values for specific integer tick labels (powers of two)
power_of_two_exponents = np.arange(0, 17) # 0 to 16, as 2^16 = 65536
N_values_discrete = 2**power_of_two_exponents

# 4. Define the P values
P_values = [1.0, 0.98]

# 5. Create the plot
plt.figure(figsize=(14, 8)) # Slightly larger figure for readability

# Determine the x-position for the asymptote labels (slightly beyond the right edge of the plot)
max_N_for_plot = 65536
x_label_pos = max_N_for_plot * 1.05 # Place label 3% beyond the max N for better visibility

# Loop through each P value and plot the execution time curve
for P in P_values:
    times = execution_time_amdahl(P, N_values_dense)
    
    # Calculate the theoretical minimum execution time (as N -> infinity)
    min_time_theoretical = (1 - P) # Assuming T1=1
    
    # Plot the function line (removed min time from label as it will be on the asymptote)
    line, = plt.plot(N_values_dense, times, label=f'P={P:.2f}')
    
    # Plot the horizontal asymptote (min theoretical time)
    if min_time_theoretical > 0: # For P=1.0, min_time is 0, so no explicit asymptote above the axis
        plt.axhline(y=min_time_theoretical, 
                    color=line.get_color(), 
                    linestyle=':', 
                    alpha=0.7)
        # Add a text label for the asymptote
        plt.text(x_label_pos, min_time_theoretical, 
                 f'{min_time_theoretical:.2f}x', # Format as fraction of original time
                 color=line.get_color(), 
                 ha='right', va='bottom', 
                 fontsize=11, 
                 fontweight='bold')
    else: # For P=1.0, the asymptote is y=0
        plt.axhline(y=0, color=line.get_color(), linestyle=':', alpha=0.7)
        plt.text(x_label_pos, 0.005, # Place slightly above 0 for visibility
                 f'{min_time_theoretical:.2f}x', # Will show '0.00x'
                 color=line.get_color(), 
                 ha='left', va='top', 
                 fontsize=11, 
                 fontweight='bold')


# 6. Customize the plot
plt.xscale('log') # Keep x-axis on a logarithmic scale for distributing the points visually

# Set custom x-axis ticks and labels
plt.xticks(N_values_discrete, [str(n) for n in N_values_discrete])
plt.tick_params(axis='x', rotation=45) # Rotate labels slightly if they overlap, or use 90 for vertical

plt.xlabel('Number of Processors (N)', fontsize=12)
plt.ylabel('Execution Time (fraction of original T1)', fontsize=12)
plt.title("Amdahl's Law: Execution Time vs. Number of Processors", fontsize=14)
plt.grid(True, which="both", ls="--", c='0.7') # Show grid for both major and minor ticks
plt.legend(title='Fraction Parallel (P)', loc='upper right', fontsize=10)

plt.ylim(-0.05, 1.05)
# Extend x-axis limit to make space for labels
plt.xlim(1, max_N_for_plot * 1.05)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define the execution time function for Gustafson's Law (Weak Scaling)
def execution_time_gustafson(S_sequential_fraction, N, T_ref=1.0):
    """
    Calculates execution time according to Gustafson's Law (weak scaling).
    T_ref is the ideal execution time for the scaled problem on N processors.
    In ideal weak scaling, execution time is constant, regardless of N, 
    as long as the sequential fraction (S_sequential_fraction) is constant.
    The value of S_sequential_fraction is the portion of runtime on the N-processor system that is sequential.
    """
    # For Gustafson's Law (weak scaling), the ideal execution time for the scaled problem
    # is a constant, assuming the sequential fraction S is constant on N processors.
    # The different S values define how much "larger" problem you can solve within this time.
    # But the time itself is ideally T_ref.
    return np.full_like(N, T_ref) # Returns an array of T_ref with the same shape as N


# 2. Define the range for N (Number of Processors) for plotting dense curves
N_values_dense = np.linspace(1, 65536, 500)

# 3. Define the N values for specific integer tick labels (powers of two)
power_of_two_exponents = np.arange(0, 17) # 0 to 16, as 2^16 = 65536
N_values_discrete = 2**power_of_two_exponents

# 4. Define the P values (from Amdahl's context), which translate to S for Gustafson
P_values_amdahl = [1.0, 0.98]
# Corresponding S (sequential fraction of runtime on parallel system) for Gustafson's Law
# (If P is Amdahl's parallel fraction, then S_gustafson = 1 - P)
S_values_gustafson = [1 - p for p in P_values_amdahl] # [0.0, 0.02]

# 5. Create the plot
plt.figure(figsize=(14, 8))

# Determine the x-position for the asymptote labels (slightly beyond the right edge of the plot)
max_N_for_plot = 65536
x_label_pos = max_N_for_plot * 1.03 

# Loop through each S value and plot the execution time curve
for i, S_val in enumerate(S_values_gustafson):
    # For ideal Gustafson's Law (weak scaling), execution time is constant (T_ref = 1.0)
    times = execution_time_gustafson(S_val, N_values_dense, T_ref=1.0)
    
    # Label refers to the Amdahl's P value for consistency with user's input
    label_text = f'P={P_values_amdahl[i]:.2f} (S={S_val:.2f})'
    
    # Plot the function line - it will be a flat line
    line, = plt.plot(N_values_dense, times, label=label_text, 
                     linestyle='-' if S_val == 0.0 else '--', # Use different line styles
                     linewidth=2)
    
    # Add a text label for the execution time (which is 1.0 for all)
    # We place labels slightly offset vertically to distinguish them, even if values are identical
    vertical_offset = 0.01 if S_val == 0.0 else -0.01 # Small offset for clarity
    
    plt.text(x_label_pos, times[-1] + vertical_offset, 
             f'{times[-1]:.1f}x', # Format as relative time
             color=line.get_color(), 
             ha='left', va='center', 
             fontsize=11, 
             fontweight='bold')

# 6. Customize the plot
plt.xscale('log') 

# Set custom x-axis ticks and labels
plt.xticks(N_values_discrete, [str(n) for n in N_values_discrete])
plt.tick_params(axis='x', rotation=45) 

plt.xlabel('Number of Processors (N)', fontsize=12)
plt.ylabel('Execution Time (relative to ideal weak scaling)', fontsize=12)
plt.title("Gustafson's Law (Weak Scaling): Execution Time vs. Number of Processors", fontsize=14)
plt.grid(True, which="both", ls="--", c='0.7') 
plt.legend(title='Parallel Fraction (P) / Sequential Fraction (S)', loc='upper right', fontsize=10)

plt.ylim(0.9, 1.1) # Set y-axis limits to clearly show the flat lines around 1.0
plt.xlim(1, max_N_for_plot * 1.05) # Extend x-axis limit for labels

plt.tight_layout() 
plt.show()
